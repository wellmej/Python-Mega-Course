# %%
#----------------------------------------------------------------
# Important!!! - This Script will copy first 300 JPEG files
#                from the TRAIN library for CNN
#----------------------------------------------------------------


#----------------------------------------------------------------
# Import Necessary Libraries for CSV File and Hash Processing
#----------------------------------------------------------------

# SHA hash algorithms. 
  
#import hashlib 
#import csv

import numpy as np
import pandas as pd
import os
import shutil

# %%
FOLDER_SUBTYPE = '/train'
FILE_MAX = 300
ext = '.JPEG'

# %%
#---------------------------------------------------------------------------
# List files in a Directory/Folder with a given file extension
#---------------------------------------------------------------------------


file_list = []
SOURCE_NUMBER = "/0/"
DEST_NUMBER = "/0-0/"

#set to your working directory
# C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\0
dir_path = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + SOURCE_NUMBER
dest_folder = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + DEST_NUMBER

os.chdir(dir_path)
print("Current Working Directory " , os.getcwd())
files = os.listdir(dir_path)
for f in files:
  if f.endswith(ext):
    print("File: " , f)
    file_list.append(f)


#---------------------------------------------------------------------------
# Copy 100 files from one directory to the dest folder
#---------------------------------------------------------------------------

file_count = 1
for file_name in files:
    print (str(file_count) + ' - ' + file_name + ' to ' + dest_folder)
    shutil.copy(file_name, dest_folder)
    if file_count >= FILE_MAX:
        break
    else:
        file_count = file_count + 1
# Out:
# Current Working Directory  C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\0
# File:  ILSVRC2012_val_00000293.JPEG
# File:  ILSVRC2012_val_00002138.JPEG
# File:  ILSVRC2012_val_00003014.JPEG
# File:  ILSVRC2012_val_00006697.JPEG
# File:  ILSVRC2012_val_00007197.JPEG
# File:  ILSVRC2012_val_00009346.JPEG
# File:  ILSVRC2012_val_00009379.JPEG
# File:  ILSVRC2012_val_00009396.JPEG
# File:  ILSVRC2012_val_00010306.JPEG
# File:  ILSVRC2012_val_00011233.JPEG
# File:  ILSVRC2012_val_00011993.JPEG
# File:  ILSVRC2012_val_00012503.JPEG
# File:  ILSVRC2012_val_00013716.JPEG
# File:  ILSVRC2012_val_00016018.JPEG
# File:  ILSVRC2012_val_00017699.JPEG
# File:  ILSVRC2012_val_00017995.JPEG
# File:  ILSVRC2012_val_00018317.JPEG
# File:  ILSVRC2012_val_00023559.JPEG
# File:  ILSVRC2012_val_00024235.JPEG
# File:  ILSVRC2012_val_00024327.JPEG
# File:  ILSVRC2012_val_00025129.JPEG
# File:  ILSVRC2012_val_00025527.JPEG
# ...

# %%
#---------------------------------------------------------------------------
# List files in a Directory/Folder with a given file extension
#---------------------------------------------------------------------------


file_list = []
SOURCE_NUMBER = "/1/"
DEST_NUMBER = "/1-1/"

#set to your working directory
# C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\0
dir_path = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + SOURCE_NUMBER
dest_folder = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + DEST_NUMBER

os.chdir(dir_path)
print("Current Working Directory " , os.getcwd())
files = os.listdir(dir_path)
for f in files:
  if f.endswith(ext):
    print("File: " , f)
    file_list.append(f)


#---------------------------------------------------------------------------
# Copy 100 files from one directory to the dest folder
#---------------------------------------------------------------------------

file_count = 1
for file_name in files:
    print (str(file_count) + ' - ' + file_name + ' to ' + dest_folder)
    shutil.copy(file_name, dest_folder)
    if file_count >= FILE_MAX:
        break
    else:
        file_count = file_count + 1
# Out:
# Current Working Directory  C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\1
# File:  ILSVRC2012_val_00000665.JPEG
# File:  ILSVRC2012_val_00001968.JPEG
# File:  ILSVRC2012_val_00002294.JPEG
# File:  ILSVRC2012_val_00002315.JPEG
# File:  ILSVRC2012_val_00004548.JPEG
# File:  ILSVRC2012_val_00004553.JPEG
# File:  ILSVRC2012_val_00007568.JPEG
# File:  ILSVRC2012_val_00008334.JPEG
# File:  ILSVRC2012_val_00010994.JPEG
# File:  ILSVRC2012_val_00012689.JPEG
# File:  ILSVRC2012_val_00014125.JPEG
# File:  ILSVRC2012_val_00015499.JPEG
# File:  ILSVRC2012_val_00015694.JPEG
# File:  ILSVRC2012_val_00016768.JPEG
# File:  ILSVRC2012_val_00016833.JPEG
# File:  ILSVRC2012_val_00017664.JPEG
# File:  ILSVRC2012_val_00018207.JPEG
# File:  ILSVRC2012_val_00019414.JPEG
# File:  ILSVRC2012_val_00021016.JPEG
# File:  ILSVRC2012_val_00021205.JPEG
# File:  ILSVRC2012_val_00024246.JPEG
# File:  ILSVRC2012_val_00027918.JPEG
# ...

# %%
#---------------------------------------------------------------------------
# List files in a Directory/Folder with a given file extension
#---------------------------------------------------------------------------


file_list = []
SOURCE_NUMBER = "/2/"
DEST_NUMBER = "/2-2/"

#set to your working directory
# C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\0
dir_path = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + SOURCE_NUMBER
dest_folder = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + DEST_NUMBER

os.chdir(dir_path)
print("Current Working Directory " , os.getcwd())
files = os.listdir(dir_path)
for f in files:
  if f.endswith(ext):
    print("File: " , f)
    file_list.append(f)


#---------------------------------------------------------------------------
# Copy 100 files from one directory to the dest folder
#---------------------------------------------------------------------------

file_count = 1
for file_name in files:
    print (str(file_count) + ' - ' + file_name + ' to ' + dest_folder)
    shutil.copy(file_name, dest_folder)
    if file_count >= FILE_MAX:
        break
    else:
        file_count = file_count + 1
# Out:
# Current Working Directory  C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\2
# File:  ILSVRC2012_val_00000557.JPEG
# File:  ILSVRC2012_val_00002034.JPEG
# File:  ILSVRC2012_val_00003944.JPEG
# File:  ILSVRC2012_val_00005866.JPEG
# File:  ILSVRC2012_val_00006787.JPEG
# File:  ILSVRC2012_val_00007226.JPEG
# File:  ILSVRC2012_val_00009404.JPEG
# File:  ILSVRC2012_val_00009833.JPEG
# File:  ILSVRC2012_val_00012468.JPEG
# File:  ILSVRC2012_val_00013735.JPEG
# File:  ILSVRC2012_val_00014287.JPEG
# File:  ILSVRC2012_val_00016648.JPEG
# File:  ILSVRC2012_val_00017463.JPEG
# File:  ILSVRC2012_val_00017775.JPEG
# File:  ILSVRC2012_val_00018559.JPEG
# File:  ILSVRC2012_val_00023674.JPEG
# File:  ILSVRC2012_val_00024874.JPEG
# File:  ILSVRC2012_val_00025484.JPEG
# File:  ILSVRC2012_val_00027673.JPEG
# File:  ILSVRC2012_val_00027735.JPEG
# File:  ILSVRC2012_val_00029663.JPEG
# File:  ILSVRC2012_val_00031964.JPEG
# ...

# %%
#---------------------------------------------------------------------------
# List files in a Directory/Folder with a given file extension
#---------------------------------------------------------------------------


file_list = []
SOURCE_NUMBER = "/3/"
DEST_NUMBER = "/3-3/"

#set to your working directory
# C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\0
dir_path = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + SOURCE_NUMBER
dest_folder = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + DEST_NUMBER

os.chdir(dir_path)
print("Current Working Directory " , os.getcwd())
files = os.listdir(dir_path)
for f in files:
  if f.endswith(ext):
    print("File: " , f)
    file_list.append(f)


#---------------------------------------------------------------------------
# Copy 100 files from one directory to the dest folder
#---------------------------------------------------------------------------

file_count = 1
for file_name in files:
    print (str(file_count) + ' - ' + file_name + ' to ' + dest_folder)
    shutil.copy(file_name, dest_folder)
    if file_count >= FILE_MAX:
        break
    else:
        file_count = file_count + 1
# Out:
# Current Working Directory  C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\3
# File:  ILSVRC2012_val_00000537.JPEG
# File:  ILSVRC2012_val_00004034.JPEG
# File:  ILSVRC2012_val_00005506.JPEG
# File:  ILSVRC2012_val_00006043.JPEG
# File:  ILSVRC2012_val_00006578.JPEG
# File:  ILSVRC2012_val_00006669.JPEG
# File:  ILSVRC2012_val_00006726.JPEG
# File:  ILSVRC2012_val_00009206.JPEG
# File:  ILSVRC2012_val_00017719.JPEG
# File:  ILSVRC2012_val_00019137.JPEG
# File:  ILSVRC2012_val_00020674.JPEG
# File:  ILSVRC2012_val_00023477.JPEG
# File:  ILSVRC2012_val_00024269.JPEG
# File:  ILSVRC2012_val_00025063.JPEG
# File:  ILSVRC2012_val_00025878.JPEG
# File:  ILSVRC2012_val_00026573.JPEG
# File:  ILSVRC2012_val_00026879.JPEG
# File:  ILSVRC2012_val_00026946.JPEG
# File:  ILSVRC2012_val_00027785.JPEG
# File:  ILSVRC2012_val_00028196.JPEG
# File:  ILSVRC2012_val_00029668.JPEG
# File:  ILSVRC2012_val_00029918.JPEG
# ...

# %%
#---------------------------------------------------------------------------
# List files in a Directory/Folder with a given file extension
#---------------------------------------------------------------------------


file_list = []
SOURCE_NUMBER = "/4/"
DEST_NUMBER = "/4-4/"

#set to your working directory
# C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\0
dir_path = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + SOURCE_NUMBER
dest_folder = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + DEST_NUMBER

os.chdir(dir_path)
print("Current Working Directory " , os.getcwd())
files = os.listdir(dir_path)
for f in files:
  if f.endswith(ext):
    print("File: " , f)
    file_list.append(f)


#---------------------------------------------------------------------------
# Copy 100 files from one directory to the dest folder
#---------------------------------------------------------------------------

file_count = 1
for file_name in files:
    print (str(file_count) + ' - ' + file_name + ' to ' + dest_folder)
    shutil.copy(file_name, dest_folder)
    if file_count >= FILE_MAX:
        break
    else:
        file_count = file_count + 1
# Out:
# Current Working Directory  C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\4
# File:  ILSVRC2012_val_00004939.JPEG
# File:  ILSVRC2012_val_00005295.JPEG
# File:  ILSVRC2012_val_00005598.JPEG
# File:  ILSVRC2012_val_00006268.JPEG
# File:  ILSVRC2012_val_00008116.JPEG
# File:  ILSVRC2012_val_00009705.JPEG
# File:  ILSVRC2012_val_00014037.JPEG
# File:  ILSVRC2012_val_00015155.JPEG
# File:  ILSVRC2012_val_00016854.JPEG
# File:  ILSVRC2012_val_00016873.JPEG
# File:  ILSVRC2012_val_00016949.JPEG
# File:  ILSVRC2012_val_00017198.JPEG
# File:  ILSVRC2012_val_00017783.JPEG
# File:  ILSVRC2012_val_00023619.JPEG
# File:  ILSVRC2012_val_00024897.JPEG
# File:  ILSVRC2012_val_00027385.JPEG
# File:  ILSVRC2012_val_00029728.JPEG
# File:  ILSVRC2012_val_00031446.JPEG
# File:  ILSVRC2012_val_00033509.JPEG
# File:  ILSVRC2012_val_00033568.JPEG
# File:  ILSVRC2012_val_00034534.JPEG
# File:  ILSVRC2012_val_00035753.JPEG
# ...

# %%
#---------------------------------------------------------------------------
# List files in a Directory/Folder with a given file extension
#---------------------------------------------------------------------------


file_list = []
SOURCE_NUMBER = "/5/"
DEST_NUMBER = "/5-5/"

#set to your working directory
# C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\0
dir_path = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + SOURCE_NUMBER
dest_folder = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + DEST_NUMBER

os.chdir(dir_path)
print("Current Working Directory " , os.getcwd())
files = os.listdir(dir_path)
for f in files:
  if f.endswith(ext):
    print("File: " , f)
    file_list.append(f)


#---------------------------------------------------------------------------
# Copy 100 files from one directory to the dest folder
#---------------------------------------------------------------------------

file_count = 1
for file_name in files:
    print (str(file_count) + ' - ' + file_name + ' to ' + dest_folder)
    shutil.copy(file_name, dest_folder)
    if file_count >= FILE_MAX:
        break
    else:
        file_count = file_count + 1
# Out:
# Current Working Directory  C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\5
# File:  ILSVRC2012_val_00000957.JPEG
# File:  ILSVRC2012_val_00003587.JPEG
# File:  ILSVRC2012_val_00003759.JPEG
# File:  ILSVRC2012_val_00005548.JPEG
# File:  ILSVRC2012_val_00005554.JPEG
# File:  ILSVRC2012_val_00007155.JPEG
# File:  ILSVRC2012_val_00007536.JPEG
# File:  ILSVRC2012_val_00007985.JPEG
# File:  ILSVRC2012_val_00009037.JPEG
# File:  ILSVRC2012_val_00013113.JPEG
# File:  ILSVRC2012_val_00013915.JPEG
# File:  ILSVRC2012_val_00017407.JPEG
# File:  ILSVRC2012_val_00019593.JPEG
# File:  ILSVRC2012_val_00022204.JPEG
# File:  ILSVRC2012_val_00022754.JPEG
# File:  ILSVRC2012_val_00023056.JPEG
# File:  ILSVRC2012_val_00024837.JPEG
# File:  ILSVRC2012_val_00025583.JPEG
# File:  ILSVRC2012_val_00028399.JPEG
# File:  ILSVRC2012_val_00028723.JPEG
# File:  ILSVRC2012_val_00030728.JPEG
# File:  ILSVRC2012_val_00033784.JPEG
# ...

# %%
#---------------------------------------------------------------------------
# List files in a Directory/Folder with a given file extension
#---------------------------------------------------------------------------


file_list = []
SOURCE_NUMBER = "/6/"
DEST_NUMBER = "/6-6/"

#set to your working directory
# C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\0
dir_path = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + SOURCE_NUMBER
dest_folder = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + DEST_NUMBER

os.chdir(dir_path)
print("Current Working Directory " , os.getcwd())
files = os.listdir(dir_path)
for f in files:
  if f.endswith(ext):
    print("File: " , f)
    file_list.append(f)


#---------------------------------------------------------------------------
# Copy 100 files from one directory to the dest folder
#---------------------------------------------------------------------------

file_count = 1
for file_name in files:
    print (str(file_count) + ' - ' + file_name + ' to ' + dest_folder)
    shutil.copy(file_name, dest_folder)
    if file_count >= FILE_MAX:
        break
    else:
        file_count = file_count + 1
# Out:
# Current Working Directory  C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\6
# File:  ILSVRC2012_val_00001144.JPEG
# File:  ILSVRC2012_val_00002434.JPEG
# File:  ILSVRC2012_val_00004119.JPEG
# File:  ILSVRC2012_val_00005094.JPEG
# File:  ILSVRC2012_val_00005744.JPEG
# File:  ILSVRC2012_val_00006234.JPEG
# File:  ILSVRC2012_val_00007477.JPEG
# File:  ILSVRC2012_val_00007519.JPEG
# File:  ILSVRC2012_val_00009345.JPEG
# File:  ILSVRC2012_val_00012925.JPEG
# File:  ILSVRC2012_val_00013827.JPEG
# File:  ILSVRC2012_val_00013925.JPEG
# File:  ILSVRC2012_val_00013958.JPEG
# File:  ILSVRC2012_val_00016208.JPEG
# File:  ILSVRC2012_val_00018227.JPEG
# File:  ILSVRC2012_val_00019147.JPEG
# File:  ILSVRC2012_val_00021253.JPEG
# File:  ILSVRC2012_val_00025379.JPEG
# File:  ILSVRC2012_val_00025416.JPEG
# File:  ILSVRC2012_val_00026865.JPEG
# File:  ILSVRC2012_val_00028914.JPEG
# File:  ILSVRC2012_val_00029377.JPEG
# ...

# %%
#---------------------------------------------------------------------------
# List files in a Directory/Folder with a given file extension
#---------------------------------------------------------------------------


file_list = []
SOURCE_NUMBER = "/7/"
DEST_NUMBER = "/7-7/"

#set to your working directory
# C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\0
dir_path = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + SOURCE_NUMBER
dest_folder = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + DEST_NUMBER

os.chdir(dir_path)
print("Current Working Directory " , os.getcwd())
files = os.listdir(dir_path)
for f in files:
  if f.endswith(ext):
    print("File: " , f)
    file_list.append(f)


#---------------------------------------------------------------------------
# Copy 100 files from one directory to the dest folder
#---------------------------------------------------------------------------

file_count = 1
for file_name in files:
    print (str(file_count) + ' - ' + file_name + ' to ' + dest_folder)
    shutil.copy(file_name, dest_folder)
    if file_count >= FILE_MAX:
        break
    else:
        file_count = file_count + 1
# Out:
# Current Working Directory  C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\7
# File:  ILSVRC2012_val_00002049.JPEG
# File:  ILSVRC2012_val_00002498.JPEG
# File:  ILSVRC2012_val_00005183.JPEG
# File:  ILSVRC2012_val_00005996.JPEG
# File:  ILSVRC2012_val_00006434.JPEG
# File:  ILSVRC2012_val_00006909.JPEG
# File:  ILSVRC2012_val_00007186.JPEG
# File:  ILSVRC2012_val_00009279.JPEG
# File:  ILSVRC2012_val_00012504.JPEG
# File:  ILSVRC2012_val_00013436.JPEG
# File:  ILSVRC2012_val_00015654.JPEG
# File:  ILSVRC2012_val_00017466.JPEG
# File:  ILSVRC2012_val_00017469.JPEG
# File:  ILSVRC2012_val_00017866.JPEG
# File:  ILSVRC2012_val_00018006.JPEG
# File:  ILSVRC2012_val_00018516.JPEG
# File:  ILSVRC2012_val_00019256.JPEG
# File:  ILSVRC2012_val_00019667.JPEG
# File:  ILSVRC2012_val_00022538.JPEG
# File:  ILSVRC2012_val_00023044.JPEG
# File:  ILSVRC2012_val_00024806.JPEG
# File:  ILSVRC2012_val_00029203.JPEG
# ...

# %%
#---------------------------------------------------------------------------
# List files in a Directory/Folder with a given file extension
#---------------------------------------------------------------------------


file_list = []
SOURCE_NUMBER = "/8/"
DEST_NUMBER = "/8-8/"

#set to your working directory
# C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\0
dir_path = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + SOURCE_NUMBER
dest_folder = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + DEST_NUMBER

os.chdir(dir_path)
print("Current Working Directory " , os.getcwd())
files = os.listdir(dir_path)
for f in files:
  if f.endswith(ext):
    print("File: " , f)
    file_list.append(f)


#---------------------------------------------------------------------------
# Copy 100 files from one directory to the dest folder
#---------------------------------------------------------------------------

file_count = 1
for file_name in files:
    print (str(file_count) + ' - ' + file_name + ' to ' + dest_folder)
    shutil.copy(file_name, dest_folder)
    if file_count >= FILE_MAX:
        break
    else:
        file_count = file_count + 1
# Out:
# Current Working Directory  C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\8
# File:  ILSVRC2012_val_00002314.JPEG
# File:  ILSVRC2012_val_00003793.JPEG
# File:  ILSVRC2012_val_00006468.JPEG
# File:  ILSVRC2012_val_00007755.JPEG
# File:  ILSVRC2012_val_00007947.JPEG
# File:  ILSVRC2012_val_00008599.JPEG
# File:  ILSVRC2012_val_00011983.JPEG
# File:  ILSVRC2012_val_00012356.JPEG
# File:  ILSVRC2012_val_00012634.JPEG
# File:  ILSVRC2012_val_00013633.JPEG
# File:  ILSVRC2012_val_00016748.JPEG
# File:  ILSVRC2012_val_00017247.JPEG
# File:  ILSVRC2012_val_00019268.JPEG
# File:  ILSVRC2012_val_00023215.JPEG
# File:  ILSVRC2012_val_00023845.JPEG
# File:  ILSVRC2012_val_00024405.JPEG
# File:  ILSVRC2012_val_00026194.JPEG
# File:  ILSVRC2012_val_00030938.JPEG
# File:  ILSVRC2012_val_00031486.JPEG
# File:  ILSVRC2012_val_00031744.JPEG
# File:  ILSVRC2012_val_00031897.JPEG
# File:  ILSVRC2012_val_00031954.JPEG
# ...

# %%
#---------------------------------------------------------------------------
# List files in a Directory/Folder with a given file extension
#---------------------------------------------------------------------------


file_list = []
SOURCE_NUMBER = "/9/"
DEST_NUMBER = "/9-9/"

#set to your working directory
# C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\0
dir_path = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + SOURCE_NUMBER
dest_folder = "C:/Users/jrwel/Documents/Udemy/Data Science Real-World Case Studies/Data/Case4-Imagenet/Pics" + FOLDER_SUBTYPE + DEST_NUMBER

os.chdir(dir_path)
print("Current Working Directory " , os.getcwd())
files = os.listdir(dir_path)
for f in files:
  if f.endswith(ext):
    print("File: " , f)
    file_list.append(f)


#---------------------------------------------------------------------------
# Copy 100 files from one directory to the dest folder
#---------------------------------------------------------------------------

file_count = 1
for file_name in files:
    print (str(file_count) + ' - ' + file_name + ' to ' + dest_folder)
    shutil.copy(file_name, dest_folder)
    if file_count >= FILE_MAX:
        break
    else:
        file_count = file_count + 1
# Out:
# Current Working Directory  C:\Users\jrwel\Documents\Udemy\Data Science Real-World Case Studies\Data\Case4-Imagenet\Pics\train\9
# File:  ILSVRC2012_val_00002508.JPEG
# File:  ILSVRC2012_val_00002665.JPEG
# File:  ILSVRC2012_val_00004745.JPEG
# File:  ILSVRC2012_val_00007616.JPEG
# File:  ILSVRC2012_val_00009269.JPEG
# File:  ILSVRC2012_val_00009559.JPEG
# File:  ILSVRC2012_val_00009593.JPEG
# File:  ILSVRC2012_val_00009873.JPEG
# File:  ILSVRC2012_val_00010336.JPEG
# File:  ILSVRC2012_val_00010427.JPEG
# File:  ILSVRC2012_val_00011324.JPEG
# File:  ILSVRC2012_val_00013527.JPEG
# File:  ILSVRC2012_val_00015689.JPEG
# File:  ILSVRC2012_val_00015787.JPEG
# File:  ILSVRC2012_val_00016387.JPEG
# File:  ILSVRC2012_val_00017919.JPEG
# File:  ILSVRC2012_val_00018229.JPEG
# File:  ILSVRC2012_val_00018509.JPEG
# File:  ILSVRC2012_val_00019289.JPEG
# File:  ILSVRC2012_val_00020003.JPEG
# File:  ILSVRC2012_val_00020698.JPEG
# File:  ILSVRC2012_val_00022496.JPEG
# ...

# %%
print("Current Working Directory " , os.getcwd())
from tkinter.filedialog import askopenfilename
selected_filename = askopenfilename(initialdir = dir_path, title = "Select file",filetypes = (("text files","*.txt"),("all files","*.*")))

# %%
print ("Selected File name: ", selected_filename)

# %%
from tkinter import filedialog
from tkinter import *

root = Tk()
root.filename =  filedialog.asksaveasfilename(initialdir = dir_path, title = "Select file",filetypes = (("text files","*.txt"),("all files","*.*")))
print (root.filename)
save_filename = root.filename

# %%
print ("Selected File name: ", save_filename)

# %%
#----------------------------------------------------------------
# Read CSV file into dataframe - For Future use only
#----------------------------------------------------------------

# Define the headers if necessary
#----------------------------------------
# NOTE: MTCARS_CSV has headers defined
#----------------------------------------
#headers = ["symboling", "normalized_losses", "make", "fuel_type", "aspiration",
#           "num_doors", "body_style", "drive_wheels", "engine_location",
#           "wheel_base", "length", "width", "height", "curb_weight",
#           "engine_type", "num_cylinders", "engine_size", "fuel_system",
#           "bore", "stroke", "compression_ratio", "horsepower", "peak_rpm",
#           "city_mpg", "highway_mpg", "price"]

# Read in the CSV file and convert "?" to NaN

#C:\Users\wellmej\OneDrive - Nationwide\Documents\PLD-SmartRide\SmartHome\2019 PID Info\Project Details\Data\Notion
#in_file = "C:/Users/wellmej/OneDrive - Nationwide/Documents/PLD-SmartRide/SmartHome/2019 PID Info/Project Details/Data/Notion/Ned_test1.txt"
#out_file = "C:/Users/wellmej/OneDrive - Nationwide/Documents/PLD-SmartRide/SmartHome/2019 PID Info/Project Details/Data/Notion/Ned_test1_hash.txt"
in_file = selected_filename
#out_file = "hashed_value_" + selected_filename
out_file = save_filename
#in_file = "C:/Users/wellmej/Documents/PLD-SmartRide/SmartHome/2019 PID Info/Project Details/Data/Notion/Ned_test1.txt"
df_raw = pd.read_csv(in_file, na_values="?", header=None )

#                     header=None, names=headers, na_values="?" )

# Define a list of models that we want to review
#models = ["toyota","nissan","mazda", "honda", "mitsubishi", "subaru", "volkswagen", "volvo"]

# Create a copy of the data with only the top 8 manufacturers
#df = df_raw[df_raw.make.isin(models)].copy()

# Create a copy of the data with all models
policy_in_df = df_raw

policy_in_df.head(10)

# %%
#----------------------------------------------------------------
# Important!!! - Do not run code below - it is for test only
#----------------------------------------------------------------

#display_policy_number = "HO00169861-02"
#policy_number = display_policy_number[0:10]
#
#print ('display_policy_number', display_policy_number, "<")
#print ("Policy:", policy_number, "<")

# %%
#----------------------------------------------------------------
# 1. Open Output CSV file to write Policy and Hashed data to. Set newline to null to avoid writing blank lines.
# 2. Read thru CSV inpiut file for each row
# 3. For each row, Hash the policy number, and capture last
#    8 characters of the hashed result
# 4. Write CSV output file for each new row with:
#    a. Input Policy Number
#    b. Hash SHA224 Result of Policy Number
#    c. Last 8 characters of Hash result (Activation Code)
#----------------------------------------------------------------

with open(out_file, mode='w', newline='') as hash_file_out:
      hash_file = csv.writer(hash_file_out, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        
      policy_in = open(in_file)
      policy_in_csv = csv.reader(policy_in)
      row_index = 0

#----------------------------------------------------------------
# For each input row, read the Policy_Number, hash it using
# SHA224 alogrithm, capture last 8 characters of the hash, and
# write Policy_Number, Full Hash, and Last 8 Hash to new
# output CSV file.
#----------------------------------------------------------------
      for row in policy_in_csv:
        print (row[row_index])
        row_new = row
        display_policy_number = row[row_index]
        policy_number = display_policy_number[0:10]
#
# encoding <Policy_number> using encode() 
# then sending to SHA224() 
        result = hashlib.sha224(policy_number.encode()) 
  
# printing the equivalent hexadecimal value. 
        print("The hexadecimal equivalent of SHA224 is : ")  
        print(result.hexdigest()) 

#        row_new.append(result.hexdigest()[48:] + "-jrw")
        row_new.append(result.hexdigest()[48:])        
        row_new.append(result.hexdigest())
        row_new.append(policy_number)
        
        print (row_new)
               
#----------------------------------------------------------------
#      Write out new CSV row
#----------------------------------------------------------------
        hash_file.writerow(row_new)
    
        print ("\r") 
#
# End
#

# %% [markdown]
# #### End of Policy SHA224 Hash Function

# %%
#---------------------------------------------------------------------
#---------------------------------------------------------------------
#  >>>>>  S T O P   H E R E   <<<<<<<
#---------------------------------------------------------------------
#---------------------------------------------------------------------

# %%
#----------------------------------------------------------------
# Read CSV Policy_Number file in for processing
#----------------------------------------------------------------
policy_in = open(in_file)
policy_in_csv = csv.reader(policy_in)
row_index = 0
hash_list = []

#----------------------------------------------------------------
# For each input row, read the Policy_Number, hash is using
# SHA224 alogrithm, capture last 8 characters of the hash, and
# write Policy_Number, Full Hash, and Last 8 Hash to new
# output CSV file.
#----------------------------------------------------------------
for row in policy_in_csv:
  print (row[row_index])
  row_new = row
  policy_number = row[row_index]
#
# encoding <Policy_number> using encode() 
# then sending to SHA224() 
  result = hashlib.sha224(policy_number.encode()) 
  
# printing the equivalent hexadecimal value. 
  print("The hexadecimal equivalent of SHA224 is : ")  
  print(result.hexdigest()) 

  row_new.append(result.hexdigest())
  print (row_new)
  print ("\r")
    
#  hash_file.writerow(row_new)

# %%
# Write Example


#with open(out_file, mode='w') as hash_file_out:
#    hash_file = csv.writer(hash_file_out, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

#    hash_file.writerow(row_new)

# %%
#------------------------------------
# Append Full Hash to List
#------------------------------------
#attendee_emails = []

#for row in csv_f:
#  attendee_emails.append(row[2])

#print attendee_emails

# %%
#
  
# initializing string 
policy_number = "GeeksforGeeks"
  
 
# encoding <Policy_number> using encode() 
# then sending to SHA224() 
result = hashlib.sha224(policy_number.encode()) 
  
# printing the equivalent hexadecimal value. 
print("The hexadecimal equivalent of SHA224 is : ") 
print(result.hexdigest()) 
  
print ("\r")
